# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 我寫的

# %%
def singleNumber(nums):
    for i in nums:
        if nums.count(i) == 1:
            print(i)
        else:
            pass
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 查詢到的

# %%
def singleNumber(nums):
    a = 0
    for i in nums:
        a ^= i
    return a
singleNumber([2,2,1])
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)
