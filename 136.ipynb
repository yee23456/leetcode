# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 我寫的

# %%
a = [2,2,1]
for i in a:
    if a.count(i) == 1:
        print(i)
# Out:
# 1

# %% [markdown]
# # 查詢到的

# %%
def singleNumber(nums):
    a = 0
    for i in nums:
        a ^= i
    return a
singleNumber([2,2,1])
# Out:
# 1
